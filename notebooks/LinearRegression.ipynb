# %%
# %reload_ext autoreload
# %autoreload 2
# %cd ..

# %% [markdown]
# # M5 Forecast Linear Regression Per Item-Store

# %% [markdown]
# ## Imports

# %%
import time
import os
import warnings
import numpy as np
import multiprocessing
import pandas as pd
from pathlib import Path

id_col = "id"
time_col = "date"
id_cols = ['id', 'item_id', 'dept_id', 'cat_id', 'store_id', 'state_id']

PATH_INPUT = Path("data/m5/datasets")
N_JOBS = multiprocessing.cpu_count()

HORIZON = 28  # How many days into the future to predict
VAL_DAYS = 0  # How many days of data to hold-out for validatioin (set to 0 for live)

if not PATH_INPUT.exists():
    raise FileNotFoundError("Please download the M5 dataset first by executing `src/generate_data.py`")

warnings.simplefilter("ignore")
os.environ["NIXTLA_ID_AS_COL"] = '1'
start_time = time.time()

# %% [markdown]
# # Helper Functions

# %%
from typing import List
from tqdm import tqdm
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from src.process import *

# %% [markdown]
# # Load Inputs

# %%
cal = load_calendar(PATH_INPUT)
prices = load_prices(PATH_INPUT)

df = pd.read_parquet("data/train.snap.parquet")
# df = filter_data(df, 400)
# Out:
# 2025-08-24 17:34:57.323 | DEBUG    | src.process:load_calendar:30 - Begin Loading Calendar Data...
# 2025-08-24 17:34:57.336 | DEBUG    | src.process:load_prices:44 - Begin Loading Price Data...

# %%
import warnings
from tqdm.auto import tqdm

# %%
df["date"].nunique()
# Out:
# 1941

# %%
sku_id = "FOODS_2_001_CA_2_evaluation"
# df_sku = df[df["id"] == sku_id].copy()

# # # Split into training and testing sets (last 28 days for evaluation)
# train_data = df_sku.iloc[:-forecast_horizon]
# test_data = df_sku.iloc[-forecast_horizon:]

# X_train, y_train = train_data[features], train_data["y"]
# X_test, y_test = test_data[features], test_data["y"]


# if i % 1_000 == 0:
#     logger.info(f"""Training model {i} of {df["id"].nunique()} for SKU: {sku_id}""")

# pbar.set_description(f"""Training model {i:,d} of {df["id"].nunique():,d} for SKU: {sku_id}""")
# Filter data for this SKU
df_sku = df[df["id"] == sku_id].copy()

# Split into training and testing sets (last 28 days for evaluation)
train_data = df_sku.iloc[:-forecast_horizon]
test_data = df_sku.iloc[-forecast_horizon:]

X_train, y_train = train_data[features], train_data["y"]
X_test, y_test = test_data[features], test_data["y"]

# Train a Linear Regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Store last known row to generate future predictions
last_row = df_sku.iloc[-1][features].copy()

# Generate future dates
future_dates = pd.date_range(start=df_sku["date"].max() + pd.Timedelta(days=1), periods=forecast_horizon, freq="D")

# Create empty dataframe to store future predictions
future_df = pd.DataFrame({"date": future_dates})

# Copy over known features that do not change
future_df["day"] = future_df["date"].dt.day
future_df["month"] = future_df["date"].dt.month
future_df["weekday"] = future_df["date"].dt.weekday
future_df["weekofyear"] = future_df["date"].dt.isocalendar().week
future_df["sell_price"] = last_row["sell_price"]  # Assuming price remains the same

# Recursive forecasting
predictions = []
for j in range(forecast_horizon):  # Changed variable name from i to j to avoid conflict
    # Create new row with updated lag values
    new_row = future_df.iloc[j].copy()
    
    # Assign lag values from previous predictions
    if j > 0:
        new_row["y_lag_1"] = predictions[-1]  # Previous prediction as lag_1
    else:
        new_row["y_lag_1"] = last_row["y_lag_1"]
    
    new_row["y_lag_7"] = last_row["y_lag_7"] if j < 7 else predictions[-7]
    new_row["y_lag_14"] = last_row["y_lag_14"] if j < 14 else predictions[-14]
    new_row["y_lag_28"] = last_row["y_lag_28"] if j < 28 else predictions[-28]

    # I generally don't like to hide warnings... but I would need to pass a DataFrame w/ feature names to prevent it
    # That additional overhead results in 9 iterations/sec vs. 13 (~45% speed up) 
    X_future = new_row[features].values.reshape(1, -1)
    with warnings.catch_warnings():
        warnings.filterwarnings("ignore", message="X does not have valid feature names")
        pred = model.predict(X_future)[0]
    predictions.append(pred)

# Store results
future_df["forecast"] = predictions
future_df["id"] = sku_id

# %%
# from src.plots import *
# f, ax = plt.subplots(figsize=(10, 6))
# future_df.plot(x="date", y="forecast", title=f"Forecast vs Actual for SKU: {sku_id}", ax=ax)
# pd.Series(model.predict(X_test).round(0), index=test_data["date"]).plot(ax=ax)
# plt.show()

# %%
# Train a Linear Regression model
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Out:
# array([1., 1., 1., 2., 2., 2., 2., 1., 1., 1., 2., 1., 2., 2., 1., 1., 1.,
#        2., 2., 2., 2., 1., 1., 1., 2., 2., 2., 2.])

# %% [markdown]
# ## Try Fitting Linear Regression for Each SKU

# %%
# Feature Engineering: Extract time-based features
df["day"] = df["date"].dt.day
df["month"] = df["date"].dt.month
df["weekday"] = df["date"].dt.weekday
df["weekofyear"] = df["date"].dt.isocalendar().week

# Create lag features (e.g., past sales as features)
for lag in [1, 7, 14, 28]:
    df[f"y_lag_{lag}"] = df.groupby("id", observed=False)["y"].shift(lag)

# Drop NaN values after lag creation
df = df.dropna()

# Select features
features = ["day", "month", "weekday", "weekofyear", "sell_price", "y_lag_1", "y_lag_7", "y_lag_14", "y_lag_28"]

# Forecast Horizon
forecast_horizon = 28  # Predict next 28 days

# Store predictions
forecast_results = []


pbar = tqdm(enumerate(df["id"].unique()))

# Train a separate model for each SKU
for i, sku_id in pbar:
    
    pbar.set_description(f"""Training model {i:,d} of {df["id"].nunique():,d} for SKU: {sku_id}""")

    if i % 1_000 == 0:
        logger.info(f"""Training model {i:,d} of {df["id"].nunique():,d} for SKU: {sku_id}""")
    
    df_sku = df[df["id"] == sku_id].copy()

    # Split into training and testing sets (last 28 days for evaluation)
    train_data = df_sku.iloc[:-forecast_horizon]
    test_data = df_sku.iloc[-forecast_horizon:]

    X_train, y_train = train_data[features], train_data["y"]
    X_test, y_test = test_data[features], test_data["y"]

    # Train a Linear Regression model
    model = LinearRegression()
    model.fit(X_train, y_train)

    # Store last known row to generate future predictions
    last_row = df_sku.iloc[-1][features].copy()

    # Generate future dates
    future_dates = pd.date_range(start=df_sku["date"].max() + pd.Timedelta(days=1), periods=forecast_horizon, freq="D")

    # Create empty dataframe to store future predictions
    future_df = pd.DataFrame({"date": future_dates})

    # Copy over known features that do not change
    future_df["day"] = future_df["date"].dt.day
    future_df["month"] = future_df["date"].dt.month
    future_df["weekday"] = future_df["date"].dt.weekday
    future_df["weekofyear"] = future_df["date"].dt.isocalendar().week
    future_df["sell_price"] = last_row["sell_price"]  # Assuming price remains the same

    # Recursive forecasting
    predictions = []
    for j in range(forecast_horizon):  # Changed variable name from i to j to avoid conflict
        # Create new row with updated lag values
        new_row = future_df.iloc[j].copy()
        
        # Assign lag values from previous predictions
        if j > 0:
            new_row["y_lag_1"] = predictions[-1]  # Previous prediction as lag_1
        else:
            new_row["y_lag_1"] = last_row["y_lag_1"]
        
        new_row["y_lag_7"] = last_row["y_lag_7"] if j < 7 else predictions[-7]
        new_row["y_lag_14"] = last_row["y_lag_14"] if j < 14 else predictions[-14]
        new_row["y_lag_28"] = last_row["y_lag_28"] if j < 28 else predictions[-28]

        # I generally don't like to hide warnings... but I would need to pass a DataFrame w/ feature names to prevent it
        # That additional overhead results in 9 iterations/sec vs. 13 (~45% speed up) 
        X_future = new_row[features].values.reshape(1, -1)
        with warnings.catch_warnings():
            warnings.filterwarnings("ignore", message="X does not have valid feature names")
            pred = model.predict(X_future)[0]
        predictions.append(pred)

    # Store results
    future_df["forecast"] = predictions
    future_df["id"] = sku_id
    forecast_results.append(future_df)
# Out:
# 0it [00:00, ?it/s]
# 2025-08-24 17:40:30.635 | INFO     | __main__:<module>:32 - Training model 0 of 30,490 for SKU: FOODS_1_001_CA_1_evaluation
# 2025-08-24 17:44:16.877 | INFO     | __main__:<module>:32 - Training model 1,000 of 30,490 for SKU: FOODS_1_103_CA_1_evaluation
# 2025-08-24 17:48:11.340 | INFO     | __main__:<module>:32 - Training model 2,000 of 30,490 for SKU: FOODS_1_204_CA_1_evaluation
# 2025-08-24 17:52:12.729 | INFO     | __main__:<module>:32 - Training model 3,000 of 30,490 for SKU: FOODS_2_085_CA_1_evaluation
# 2025-08-24 17:56:24.089 | INFO     | __main__:<module>:32 - Training model 4,000 of 30,490 for SKU: FOODS_2_186_CA_1_evaluation
# 2025-08-24 18:00:34.908 | INFO     | __main__:<module>:32 - Training model 5,000 of 30,490 for SKU: FOODS_2_286_CA_1_evaluation
# 2025-08-24 18:04:45.901 | INFO     | __main__:<module>:32 - Training model 6,000 of 30,490 for SKU: FOODS_2_386_CA_1_evaluation
# 2025-08-24 18:08:57.038 | INFO     | __main__:<module>:32 - Training model 7,000 of 30,490 for SKU: FOODS_3_088_CA_1_evaluation
# 2025-08-24 18:13:06.876 | INFO     | __main__:<module>:32 - Training model 8,000 of 30,490 for SKU: FOODS_3_188_CA_1_evaluation
# 2025-08-24 18:17:18.853 | INFO     | __main__:<module>:32 - Training model 9,000 of 30,490 for SKU: FOODS_3_288_CA_1_evaluation
# 2025-08-24 18:21:29.921 | INFO     | __main__:<module>:32 - Training model 10,000 of 30,490 for SKU: FOODS_3_388_CA_1_evaluation
# 2025-08-24 18:25:40.980 | INFO     | __main__:<module>:32 - Training model 11,000 of 30,490 for SKU: FOODS_3_488_CA_1_evaluation
# 2025-08-24 18:29:52.802 | INFO     | __main__:<module>:32 - Training model 12,000 of 30,490 for SKU: FOODS_3_588_CA_1_evaluation
# 2025-08-24 18:34:03.423 | INFO     | __main__:<module>:32 - Training model 13,000 of 30,490 for SKU: FOODS_3_688_CA_1_evaluation
# 2025-08-24 18:38:13.265 | INFO     | __main__:<module>:32 - Training model 14,000 of 30,490 for SKU: FOODS_3_791_CA_1_evaluation
# 2025-08-24 18:42:24.006 | INFO     | __main__:<module>:32 - Training model 15,000 of 30,490 for SKU: HOBBIES_1_065_CA_1_evaluation
# 2025-08-24 18:46:33.366 | INFO     | __main__:<module>:32 - Training model 16,000 of 30,490 for SKU: HOBBIES_1_168_CA_1_evaluation
# 2025-08-24 18:50:24.024 | INFO     | __main__:<module>:32 - Training model 17,000 of 30,490 for SKU: HOBBIES_1_271_CA_1_evaluation
# 2025-08-24 18:54:11.439 | INFO     | __main__:<module>:32 - Training model 18,000 of 30,490 for SKU: HOBBIES_1_372_CA_1_evaluation
# 2025-08-24 18:58:01.122 | INFO     | __main__:<module>:32 - Training model 19,000 of 30,490 for SKU: HOBBIES_2_048_CA_1_evaluation
# 2025-08-24 19:02:15.837 | INFO     | __main__:<module>:32 - Training model 20,000 of 30,490 for SKU: HOBBIES_2_148_CA_1_evaluation
# 2025-08-24 19:06:27.665 | INFO     | __main__:<module>:32 - Training model 21,000 of 30,490 for SKU: HOUSEHOLD_1_102_CA_1_evaluation
# 2025-08-24 19:10:39.306 | INFO     | __main__:<module>:32 - Training model 22,000 of 30,490 for SKU: HOUSEHOLD_1_203_CA_1_evaluation
# 2025-08-24 19:14:49.443 | INFO     | __main__:<module>:32 - Training model 23,000 of 30,490 for SKU: HOUSEHOLD_1_305_CA_1_evaluation
# 2025-08-24 19:19:01.852 | INFO     | __main__:<module>:32 - Training model 24,000 of 30,490 for SKU: HOUSEHOLD_1_408_CA_1_evaluation
# 2025-08-24 19:23:23.935 | INFO     | __main__:<module>:32 - Training model 25,000 of 30,490 for SKU: HOUSEHOLD_1_508_CA_1_evaluation
# 2025-08-24 19:29:33.760 | INFO     | __main__:<module>:32 - Training model 26,000 of 30,490 for SKU: HOUSEHOLD_2_067_CA_1_evaluation
# 2025-08-24 19:35:56.974 | INFO     | __main__:<module>:32 - Training model 27,000 of 30,490 for SKU: HOUSEHOLD_2_167_CA_1_evaluation
# 2025-08-24 19:42:07.755 | INFO     | __main__:<module>:32 - Training model 28,000 of 30,490 for SKU: HOUSEHOLD_2_268_CA_1_evaluation
# 2025-08-24 19:48:22.789 | INFO     | __main__:<module>:32 - Training model 29,000 of 30,490 for SKU: HOUSEHOLD_2_368_CA_1_evaluation
# 2025-08-24 19:54:20.225 | INFO     | __main__:<module>:32 - Training model 30,000 of 30,490 for SKU: HOUSEHOLD_2_468_CA_1_evaluation

# %%
# Combine all forecasts
forecast_df = pd.concat(forecast_results, ignore_index=True)
logger.info(f"""Finished forecasting: {forecast_df["id"].nunique():,d}""")
# Out:
# 2025-08-24 19:57:57.510 | INFO     | __main__:<module>:3 - Finished forecasting: 30,490

# %%
forecast_df = forecast_df.rename(columns={"forecast": "forecast_lr"})

# %%
forecast_df.to_parquet("data/lr_predictions.snap.parquet", index=False)

# %%
# forecast_df = pd.read_parquet("data/lr_predictions.snap.parquet")
# forecast_df
# Out:
# 30490

# %%
forecast_df.empty
# Out:
# False

# %%
forecast_df.to_parquet("lr.snap.parquet")

# %%
# def make_submission(preds: pd.DataFrame,
#                     h: int) -> pd.DataFrame:
#     wide = preds.pivot_table(index='id',
#                              columns='date',
#                              observed=True)
#     wide.columns = [f'F{i+1}' for i in range(h)]
#     wide.columns.name = None
#     wide.index.name = 'id'
#     return wide

make_submission(forecast_df, HORIZON)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[89], line 11
#       1 # def make_submission(preds: pd.DataFrame,
#       2 #                     h: int) -> pd.DataFrame:
#       3 #     wide = preds.pivot_table(index='id',
#    (...)
#       8 #     wide.index.name = 'id'
#       9 #     return wide
# ---> 11 make_submission(forecast_df, HORIZON)
#
# File c:\GIT\Github\M5\src\process.py:237, in make_submission(preds, h)
#     231 """
#     232 Create wide=submission formatted DataFrame from dataframe of long formatted predictions.
#     233 """
#     234 wide = preds.pivot_table(index='id',
#     235                          columns='date',
#     236                          observed=True)
# --> 237 wide.columns = [f'F{i+1}' for i in range(h)]
#     238 wide.columns.name = None
#     239 wide.index.name = 'id'
#
# File c:\GIT\Github\M5\.venv\lib\site-packages\pandas\core\generic.py:6332, in NDFrame.__setattr__(self, name, value)
#    6330 try:
#    6331     object.__getattribute__(self, name)
# -> 6332     return object.__setattr__(self, name, value)
#    6333 except AttributeError:
#    6334     pass
#
# File pandas/_libs/properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File c:\GIT\Github\M5\.venv\lib\site-packages\pandas\core\generic.py:814, in NDFrame._set_axis(self, axis, labels)
#     809 """
#     810 This is called from the cython code when we set the `index` attribute
#     811 directly, e.g. `series.index = [1, 2, 3]`.
#     812 """
#     813 labels = ensure_index(labels)
# --> 814 self._mgr.set_axis(axis, labels)
#     815 self._clear_item_cache()
#
# File c:\GIT\Github\M5\.venv\lib\site-packages\pandas\core\internals\managers.py:238, in BaseBlockManager.set_axis(self, axis, new_labels)
#     236 def set_axis(self, axis: AxisInt, new_labels: Index) -> None:
#     237     # Caller is responsible for ensuring we have an Index object.
# --> 238     self._validate_set_axis(axis, new_labels)
#     239     self.axes[axis] = new_labels
#
# File c:\GIT\Github\M5\.venv\lib\site-packages\pandas\core\internals\base.py:98, in DataManager._validate_set_axis(self, axis, new_labels)
#      95     pass
#      97 elif new_len != old_len:
# ---> 98     raise ValueError(
#      99         f"Length mismatch: Expected axis has {old_len} elements, new "
#     100         f"values have {new_len} elements"
#     101     )
#
# ValueError: Length mismatch: Expected axis has 168 elements, new values have 28 elements

# %%
from datasetsforecast.m5 import M5Evaluation

dfids = get_dfids()
submission = make_submission(forecast_df[["id", "date", "forecast_lr"]], HORIZON)
# submission = submission.join(dfids.set_index("id"))

df_score = M5Evaluation.evaluate("data", submission.join(dfids.set_index("id")))
model_score = df_score["wrmsse"].mean()
df_score
# Out:
#            wrmsse
# Total    0.775114
# Level1   0.522048
# Level2   0.599686
# Level3   0.703741
# Level4   0.577883
# Level5   0.690135
# Level6   0.677562
# Level7   0.773639
# Level8   0.766767
# Level9   0.838091
# Level10  1.146338
# Level11  1.041165
# Level12  0.964309

# %%
submission.to_parquet("data/submission_linear_reg.snap.parquet")

# %%
print(f"""Linear Regression wrmsse: {model_score:.4f}""")
print(f"""Notebook finished in {(time.time() - start_time) / 60:.2f}m""")
# Out:
# Linear Regression wrmsse: 0.7751
# Notebook finished in 62.08m
